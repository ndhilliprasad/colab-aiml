# %% [markdown]
# <a href="https://colab.research.google.com/github/ndhilliprasad/colab-aiml/blob/main/C1_W1_Lab01_Python_Jupyter_Soln.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **House Price Prediction**

# %% [markdown]
# ## **Load Data**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/ndhilliprasad/colab-aiml/refs/heads/main/house-data.csv')
df.columns = ["sqft", "beds", "price"]
df = df.drop("beds", axis=1)
df
# Out:
#     sqft   price
# 0   1600  329900
# 1   2400  369000
# 2   1416  232000
# 3   3000  539900
# 4   1985  299900
# 5   1534  314900
# 6   1427  198999
# 7   1380  212000
# 8   1494  242500
# 9   1940  239999
# 10  2000  347000
# 11  1890  329999
# 12  4478  699900
# 13  1268  259900
# 14  2300  449900
# 15  1320  299900
# 16  1236  199900
# 17  2609  499998
# 18  3031  599000
# 19  1767  252900
# 20  1888  255000
# 21  1604  242900
# 22  1962  259900
# 23  3890  573900
# 24  1100  249900
# 25  1458  464500
# 26  2526  469000
# 27  2200  475000
# 28  2637  299900
# 29  1839  349900
# 30  1000  169900
# 31  2040  314900
# 32  3137  579900
# 33  1811  285900
# 34  1437  249900
# 35  1239  229900
# 36  2132  345000
# 37  4215  549000
# 38  2162  287000
# 39  1664  368500
# 40  2238  329900
# 41  2567  314000
# 42  1200  299000
# 43   852  179900
# 44  1852  299900
# 45  1203  239500

# %% [markdown]
# ## **Visualization**

# %%
plt.scatter(x=df["sqft"], y=df["price"])
plt.xlabel("Area (sqft)")
plt.ylabel("Price ($)")
plt.show()

# %% [markdown]
# ## **Train the model**

# %%
from re import X
import sklearn.linear_model as LinearRegression

lr = LinearRegression.LinearRegression()

X = df[["sqft"]]
y = df["price"]

lr.fit(df[['sqft']].values, df.price)
# Out:
# LinearRegression()

# %%
plt.xlabel("Area (sqft)")
plt.ylabel("Price ($)")
plt.scatter(X, y, color='red', marker='*')
plt.plot(X, lr.predict(X.values), color='blue')
plt.show()

# %% [markdown]
# ## **Apply the model to make prediction**
